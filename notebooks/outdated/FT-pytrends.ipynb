# %%
from pytrends.request import TrendReq

# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq(retries=3,requests_args={'verify':False})
# Out:
# /home/ferdinand_t/venv/lib64/python3.7/site-packages/urllib3/connectionpool.py:1052: InsecureRequestWarning: Unverified HTTPS request is being made to host 'trends.google.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /home/ferdinand_t/venv/lib64/python3.7/site-packages/urllib3/connectionpool.py:1052: InsecureRequestWarning: Unverified HTTPS request is being made to host 'trends.google.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,

# %%
# Get Google Hot Trends data
trending_searches_df = pytrend.trending_searches()
print(trending_searches_df.head())
# Out:
#                         0
# 0                 Celtics
# 1                   Texas
# 2     First-Citizens Bank
# 3              Succession
# 4  Luxembourg vs Portugal

# %%
import pandas as pd
keywords = pytrend.suggestions(keyword="jaguar")
df = pd.DataFrame(keywords)
print(df)
# Out:
#              mid                 title                     type
# 0     /m/0h5wslk                Jaguar                 Car make
# 1       /m/043vc  Jacksonville Jaguars   American football team
# 2      /m/012x34           Jaguar Cars  Luxury vehicles company
# 3       /m/0449p                Jaguar                   Animal
# 4  /g/11byvbzrnc         Radio Silence     Book by Alice Oseman

# %%
keywords = pytrend.suggestions(keyword="Marcel Marceau")
df = pd.DataFrame(keywords)
print(df)
# Out:
#              mid                             title  \
# 0      /m/017_65                    Marcel Marceau
# 1  /g/11gwn6s0jr                        Resistance
# 2     /m/01t9qj_                       Red Skelton
# 3     /m/051jd58  The Economist Book of Obituaries
# 4  /g/11b7q84nz4                Retour en absurdie
#
#                           type
# 0                 French actor
# 1                    2020 film
# 2         American entertainer
# 3      Book by Keith Colquhoun
# 4  Novel by Stéphane De Groodt

# %%
keywords = pytrend.suggestions(keyword="France vs. Argentina")
df = pd.DataFrame(keywords)
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
kw_list=["France vs Argentina"]
pytrend.build_payload(kw_list, timeframe='today 12-m')
#pytrend.related_topics()
topic_analysis = pytrend.related_topics()
topic_analysis.values()
# Out:
# ---------------------------------------------------------------------------
# TooManyRequestsError                      Traceback (most recent call last)
# /tmp/ipykernel_16004/3856197877.py in <module>
#       1 kw_list=["France vs Argentina"]
# ----> 2 pytrend.build_payload(kw_list, timeframe='today 12-m')
#       3 #pytrend.related_topics()
#       4 topic_analysis = pytrend.related_topics()
#       5 topic_analysis.values()
#
# ~/venv/lib64/python3.7/site-packages/pytrends/request.py in build_payload(self, kw_list, cat, timeframe, geo, gprop)
#     187         self.token_payload['req'] = json.dumps(self.token_payload['req'])
#     188         # get tokens
# --> 189         self._tokens()
#     190         return
#     191
#
# ~/venv/lib64/python3.7/site-packages/pytrends/request.py in _tokens(self)
#     197             method=TrendReq.GET_METHOD,
#     198             params=self.token_payload,
# --> 199             trim_chars=4,
#     200         )['widgets']
# ...

# %%
pytrend.build_payload(kw_list=['France vs Argentina'], timeframe='2022-12-01 2022-12-31', geo='US')

# %%
df_rt = pytrend.related_topics()
df_rt
# Out:
# {'France vs Argentina': {'rising':     value formattedValue                                               link  \
#   0   81150       Breakout  /trends/explore?q=/m/02718kr&date=2022-12-01+2...
#   1   64750       Breakout  /trends/explore?q=/m/0333v_&date=2022-12-01+20...
#   2   41000       Breakout  /trends/explore?q=/m/02bp2r&date=2022-12-01+20...
#   3   36550       Breakout  /trends/explore?q=/g/11bzt_34pn&date=2022-12-0...
#   4   29400       Breakout  /trends/explore?q=/g/11g1kkw8c2&date=2022-12-0...
#   5   27700       Breakout  /trends/explore?q=/m/02k1yd&date=2022-12-01+20...
#   6   23500       Breakout  /trends/explore?q=/m/0b5gmb&date=2022-12-01+20...
#   7   22750       Breakout  /trends/explore?q=/m/0fq1625&date=2022-12-01+2...
#   8   21650       Breakout  /trends/explore?q=/m/01jygk&date=2022-12-01+20...
#   9   21300       Breakout  /trends/explore?q=/m/023vk2&date=2022-12-01+20...
#   10  19450       Breakout  /trends/explore?q=/m/01_1kk&date=2022-12-01+20...
# ...

# %%
df_rq = pytrend.related_queries()
df_rq
# Out:
# {'France vs Argentina': {'top':                                   query  value
#   0                   argentina world cup    100
#   1                      france world cup     97
#   2         world cup france vs argentina     97
#   3              france vs argentina 2022     49
#   4                     france vs morocco     43
#   5                        france morocco     39
#   6                               morocco     38
#   7                  morocco vs argentina     37
#   8                  croatia vs argentina     37
#   9                     argentina croatia     36
#   10                              croatia     35
#   11                    france vs croatia     34
#   12   argentina vs france world cup 2022     25
#   13   argentina vs france 2022 world cup     25
#   14                   croatia vs morocco     23
#   15             argentina vs france live     17
#   16             fifa argentina vs france     16
#   17            argentina vs france final     16
# ...

# %%
import pandas as pd
keywords = pytrend.suggestions(keyword=trending_searches_df[0][4])
df = pd.DataFrame(keywords)

# %%
pytrend.build_payload(kw_list=[''], timeframe='2022-12-08 2022-12-08')
df_rt_test = pytrend.realtime_trending_searches()
df_rt_test
# Out:
# /home/ferdinand_t/venv/lib64/python3.7/site-packages/urllib3/connectionpool.py:1052: InsecureRequestWarning: Unverified HTTPS request is being made to host 'trends.google.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /home/ferdinand_t/venv/lib64/python3.7/site-packages/urllib3/connectionpool.py:1052: InsecureRequestWarning: Unverified HTTPS request is being made to host 'trends.google.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /home/ferdinand_t/venv/lib64/python3.7/site-packages/urllib3/connectionpool.py:1052: InsecureRequestWarning: Unverified HTTPS request is being made to host 'trends.google.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
# ...

# %%
import time
daily_trending_searches = pd.DataFrame()

for i in [dr.strftime('%Y-%m-%d') for dr in pd.date_range('20221208','20221209')]:
    try:
        pytrend.build_payload(kw_list=[''], timeframe=i + ' ' + i)
        df_rt_test = pytrend.related_topics()
        data = df_rt_test['']['rising']
        time.sleep(12)
    except requests.exceptions.Timeout:
        print('Timeout')
print(i)
daily_trending_searches = daily_trending_searches.append(data)
# Out:
# /home/ferdinand_t/venv/lib64/python3.7/site-packages/urllib3/connectionpool.py:1052: InsecureRequestWarning: Unverified HTTPS request is being made to host 'trends.google.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /home/ferdinand_t/venv/lib64/python3.7/site-packages/urllib3/connectionpool.py:1052: InsecureRequestWarning: Unverified HTTPS request is being made to host 'trends.google.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /home/ferdinand_t/venv/lib64/python3.7/site-packages/urllib3/connectionpool.py:1052: InsecureRequestWarning: Unverified HTTPS request is being made to host 'trends.google.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
# ...

# %%
daily_trending_searches
# Out:
#    value formattedValue                                               link  \
# 0  14050       Breakout  /trends/explore?q=/m/050792&date=2022-12-08+20...
# 1  12750       Breakout  /trends/explore?q=/g/11gy4y0_mx&date=2022-12-0...
# 2   9350       Breakout  /trends/explore?q=/m/07n_81&date=2022-12-08+20...
# 3   8700       Breakout  /trends/explore?q=/m/04g1phz&date=2022-12-08+2...
# 4    250          +250%  /trends/explore?q=/m/01pgj4&date=2022-12-08+20...
# 5    170          +170%  /trends/explore?q=/m/06bnz&date=2022-12-08+202...
# 6    140          +140%  /trends/explore?q=/m/06b_j&date=2022-12-08+202...
# 7     40           +40%  /trends/explore?q=/m/0d1w9&date=2022-12-08+202...
#
#        topic_mid            topic_title  \
# 0      /m/050792            Viktor Bout
# 1  /g/11gy4y0_mx            Paul Whelan
# 2      /m/07n_81  Stiff-person syndrome
# 3     /m/04g1phz        Brittney Griner
# 4      /m/01pgj4               Syndrome
# 5       /m/06bnz                 Russia
# ...

# %%
for i in [dr.strftime('%Y-%m-%d') for dr in pd.date_range('20221208','20221210')]:
    print(str( i + ' ' + i))
# Out:
# 2022-12-08 2022-12-08
# 2022-12-09 2022-12-09
# 2022-12-10 2022-12-10

# %%
pytrend.categories()
# Out:
# {'children': [{'children': [{'name': 'Celebrities & Entertainment News',
#      'id': 184},
#     {'children': [{'name': 'Animated Films', 'id': 1104},
#       {'name': 'Anime & Manga', 'id': 317},
#       {'name': 'Cartoons', 'id': 319},
#       {'name': 'Comics', 'id': 318}],
#      'name': 'Comics & Animation',
#      'id': 316},
#     {'children': [{'children': [{'name': 'Film & TV Awards', 'id': 1108},
#         {'name': 'Film & TV Production', 'id': 1117}],
#        'name': 'Film & TV Industry',
#        'id': 1116},
#       {'children': [{'name': 'Music Awards', 'id': 1113},
#         {'name': 'Record Labels', 'id': 1114}],
#        'name': 'Recording Industry',
#        'id': 1115}],
#      'name': 'Entertainment Industry',
#      'id': 612},
#     {'children': [{'name': 'Clubs & Nightlife', 'id': 188},
#       {'name': 'Concerts & Music Festivals', 'id': 891},
#       {'name': 'Film Festivals', 'id': 1086},
#       {'name': 'Live Sporting Events', 'id': 1273},
# ...

# %%
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Get Google Hot Trends data
today_searches_df = pytrend.today_searches(pn='US')
print(today_searches_df.head())
# Out:
# 0        /trends/explore?q=Celtics&date=now+7-d&geo=US
# 1          /trends/explore?q=Texas&date=now+7-d&geo=US
# 2    /trends/explore?q=Selena+Gomez+and+Zayn&date=n...
# 3    /trends/explore?q=First-Citizens+Bank&date=now...
# Name: exploreLink, dtype: object

# %%
today_searches_df
# Out:
# 0        /trends/explore?q=Celtics&date=now+7-d&geo=US
# 1          /trends/explore?q=Texas&date=now+7-d&geo=US
# 2    /trends/explore?q=Selena+Gomez+and+Zayn&date=n...
# 3    /trends/explore?q=First-Citizens+Bank&date=now...
# Name: exploreLink, dtype: object

# %%
top_charts_df = pytrend.top_charts(2018, hl='en-US', tz=300, geo='GLOBAL')
print(top_charts_df.head())
# Out:
#            title exploreQuery
# 0      World Cup
# 1         Avicii
# 2     Mac Miller
# 3       Stan Lee
# 4  Black Panther

# %%
top_charts_df.shape
# Out:
# (10, 2)

# %%
rtst_US=pytrend.realtime_trending_searches() # realtime search trends for United States
rtst_US
# Out:
# /home/ferdinand_t/venv/lib64/python3.7/site-packages/urllib3/connectionpool.py:1052: InsecureRequestWarning: Unverified HTTPS request is being made to host 'trends.google.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
#                                                 title  \
# 0                             School shooting, School
# 1   Galaxy, Black hole, Supermassive black hole, E...
# 2   NASCAR, Richmond Raceway, NASCAR Cup Series, T...
# 3   School, United States Secretary of Education, ...
# 4   Uruguay national football team, Japan national...
# ..                                                ...
# 94  Planet, Venus, Jupiter, Uranus, Mars, Night sk...
# 95  Kristen Anderson-Lopez, Robert Lopez, The Walt...
# 96  St. Mary's County, Gender identity, Maryland, ...
# 97  Glenn Youngkin, Virginia, Eldor Automotive Pow...
# ...

# %%
rtst_US=pytrend.realtime_trending_searches(pn='US') # realtime search trends for United States
rtst_US
# Out:
#                                                 title  \
# 0                              Vladimir Duthiers, CBS
# 1              New York Mets, Tim Locastro, Darin Ruf
# 2   Nick Cannon, Antisemitism, Biz Markie, Semitic...
# 3       Kelly Clarkson, Brandon Blackstock, Las Vegas
# 4              Rainbowland, Miley Cyrus, Dolly Parton
# ..                                                ...
# 82  Environmental, social, and corporate governanc...
# 83  Poole Harbour, Oil spill, Dorset, Petroleum, H...
# 84              EnBW, Coal, Finance, Renewable energy
# 85  Barrow Neurological Institute, Neurology, Pedi...
# 86  Toni Collette, Amazon Prime Video, John Leguiz...
#
#                                           entityNames
# 0                            [Vladimir Duthiers, CBS]
# 1            [New York Mets, Tim Locastro, Darin Ruf]
# 2   [Nick Cannon, Antisemitism, Biz Markie, Semiti...
# 3     [Kelly Clarkson, Brandon Blackstock, Las Vegas]
# ...

# %%
pytrend.top30in30(pn='US')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_16004/379723157.py in <module>
# ----> 1 pytrend.top30in30(pn='US')
#
# AttributeError: 'TrendReq' object has no attribute 'top30in30'
